# %%
# No. of opioid prescribers out of the total prescribers
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# Load Drug Prescriber Data in Pandas Dataframe
drug_prescriber_df = pd.read_csv("prescriber_information.csv")
drug_prescriber_df.head()
# Out:
#           NPI Gender  ... ZOLPIDEM.TARTRATE Opioid.Prescriber
# 0  1710982582      M  ...                 0                 1
# 1  1245278100      F  ...                35                 1
# 2  1427182161      F  ...                25                 0
# 3  1669567541      M  ...                 0                 1
# 4  1679650949      M  ...                 0                 1
#
# [5 rows x 256 columns]

# %%
# Load Overdose Deaths Data in Pandas Dataframe
overdose_df = pd.read_csv("overdose_deaths.csv")
overdose_df.head()
# Out:
#         State  Population Deaths Abbrev
# 0     Alabama   4,833,722    723     AL
# 1      Alaska     735,132    124     AK
# 2     Arizona   6,626,624  1,211     AZ
# 3    Arkansas   2,959,373    356     AR
# 4  California  38,332,521  4,521     CA

# %%
# Load Overdose Deaths Data in Pandas Dataframe
opioid_df = pd.read_csv("opioid_drug_list.csv")
opioid_df.head()
# Out:
#                         Drug Name                    Generic Name
# 0                         ABSTRAL                FENTANYL CITRATE
# 1           ACETAMINOPHEN-CODEINE      ACETAMINOPHEN WITH CODEINE
# 2                           ACTIQ                FENTANYL CITRATE
# 3             ASCOMP WITH CODEINE  CODEINE/BUTALBITAL/ASA/CAFFEIN
# 4  ASPIRIN-CAFFEINE-DIHYDROCODEIN  DIHYDROCODEINE/ASPIRIN/CAFFEIN

# %%
# Check for Missing Values
print("Drug Prescriber Data= ", drug_prescriber_df.isnull().values.any())
print("Overdose Data= ", overdose_df.isnull().values.any())
print("Drug List Data= ", opioid_df.isnull().values.any())
# Out:
# Drug Prescriber Data=  True
# Overdose Data=  False
# Drug List Data=  False

# %%
drug_prescriber_df.isnull().sum()
import numpy as np
# Drug Prescriber Dataset Cleaning Credentials Column - Replace Missing Values with String Value
drug_prescriber_df.Credentials = drug_prescriber_df.Credentials.fillna('UNKNOWN')

# Clean Up States from Prescriber Data to match the list of states in Overdose Death Data
drug_prescriber_df= drug_prescriber_df[drug_prescriber_df.State != 'AE']
drug_prescriber_df = drug_prescriber_df[drug_prescriber_df.State != 'ZZ']
drug_prescriber_df = drug_prescriber_df[drug_prescriber_df.State != 'AA']
drug_prescriber_df = drug_prescriber_df[drug_prescriber_df.State != 'PR']
drug_prescriber_df = drug_prescriber_df[drug_prescriber_df.State != 'GU']
drug_prescriber_df = drug_prescriber_df[drug_prescriber_df.State != 'VI']

# Overdoses Data - Removing Commas in Numerical Values
overdose_df['Deaths'] = overdose_df['Deaths'].str.replace(',', '')
overdose_df['Deaths'] = overdose_df['Deaths'].astype(int)
overdose_df['Population'] = overdose_df['Population'].str.replace(',', '')
overdose_df['Population'] = overdose_df['Population'].astype(int)

# Calculating Death Density statewise with respect to population
overdose_df['Deaths/Population'] = (overdose_df['Deaths']/overdose_df['Population'])
overdose_df.head()
# Out:
#         State  Population  Deaths Abbrev  Deaths/Population
# 0     Alabama     4833722     723     AL           0.000150
# 1      Alaska      735132     124     AK           0.000169
# 2     Arizona     6626624    1211     AZ           0.000183
# 3    Arkansas     2959373     356     AR           0.000120
# 4  California    38332521    4521     CA           0.000118

# %%
import re
drug_name = opioid_df['Drug Name']
drug_name = drug_name.apply(lambda x:re.sub("\ |-",".",str(x)))
drug_name
# Considering Features which are related to opioid compounds
opioid_drug_names = set(drug_prescriber_df.columns).intersection(set(drug_name))
opioid_drug_columns = []
# Removing redundant columns
for each in drug_prescriber_df.columns:
    if each in opioid_drug_names:
        pass
    else:
        opioid_drug_columns.append(each)
        
drug_prescriber_df = drug_prescriber_df[opioid_drug_columns]
drug_prescriber_df.head()
# Out:
#           NPI Gender  ... ZOLPIDEM.TARTRATE Opioid.Prescriber
# 0  1710982582      M  ...                 0                 1
# 1  1245278100      F  ...                35                 1
# 2  1427182161      F  ...                25                 0
# 3  1669567541      M  ...                 0                 1
# 4  1679650949      M  ...                 0                 1
#
# [5 rows x 245 columns]

# %%
drug_prescriber_df = drug_prescriber_df.drop(drug_prescriber_df.columns[[0, 3]], axis=1) 
drug_prescriber_df.head()
# Out:
#   Gender State  ... ZOLPIDEM.TARTRATE  Opioid.Prescriber
# 0      M    TX  ...                 0                  1
# 1      F    AL  ...                35                  1
# 2      F    NY  ...                25                  0
# 3      M    AZ  ...                 0                  1
# 4      M    NV  ...                 0                  1
#
# [5 rows x 243 columns]

# %%
# Convert Categorical Columns
categorical_columns = ['Gender','State','Specialty']

for column in categorical_columns:
    drug_prescriber_df[column] = pd.factorize(drug_prescriber_df[column], sort=True)[0]
drug_prescriber_df.head()
# Out:
#    Gender  State  ...  ZOLPIDEM.TARTRATE  Opioid.Prescriber
# 0       1     43  ...                  0                  1
# 1       0      1  ...                 35                  1
# 2       0     34  ...                 25                  0
# 3       1      3  ...                  0                  1
# 4       1     33  ...                  0                  1
#
# [5 rows x 243 columns]

# %%
#creating a dataset for the neural network, I am getting only the drug components values
data = drug_prescriber_df.values
X = data[:,3:]
X = X[:,:X.shape[1]-1]
y = data[:,data.shape[1]-1]
y.shape
# Out:
# (24759,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# %%
#training the neural network on GPU
from tensorflow.keras.models import Model, Sequential 
from tensorflow.keras.layers import Dense, Activation
import tensorflow.keras.backend as K 
K.clear_session()
nin= X_train.shape[1]
nout = 1
nh = 256
nh2 = 56
classifier = Sequential()
#First Hidden Layer
classifier.add(Dense(nh, activation='relu', kernel_initializer='random_normal', input_dim=nin))
#Second  Hidden Layer
classifier.add(Dense(nh2, activation='relu', kernel_initializer='random_normal'))
#Output Layer
classifier.add(Dense(1, activation='sigmoid', kernel_initializer='random_normal'))
classifier.compile(optimizer ='adam',loss='binary_crossentropy', metrics =['accuracy'])
classifier.fit(X_train,y_train, batch_size=100, epochs=100)
# Out:
# Epoch 1/100
# 17331/17331 [==============================] - 1s 48us/sample - loss: 0.5112 - acc: 0.7514
# Epoch 2/100
# 17331/17331 [==============================] - 1s 41us/sample - loss: 0.4453 - acc: 0.8135
# Epoch 3/100
# 17331/17331 [==============================] - 1s 40us/sample - loss: 0.4044 - acc: 0.8379
# Epoch 4/100
# 17331/17331 [==============================] - 1s 41us/sample - loss: 0.3694 - acc: 0.8440
# Epoch 5/100
# 17331/17331 [==============================] - 1s 40us/sample - loss: 0.3373 - acc: 0.8524
# Epoch 6/100
# 17331/17331 [==============================] - 1s 46us/sample - loss: 0.3206 - acc: 0.8577
# Epoch 7/100
# 17331/17331 [==============================] - 1s 47us/sample - loss: 0.2990 - acc: 0.8664
# Epoch 8/100
# 17331/17331 [==============================] - 1s 48us/sample - loss: 0.2861 - acc: 0.8701
# Epoch 9/100
# 17331/17331 [==============================] - 1s 48us/sample - loss: 0.2773 - acc: 0.8718
# Epoch 10/100
# 17331/17331 [==============================] - 1s 52us/sample - loss: 0.2655 - acc: 0.8798
# Epoch 11/100
# 17331/17331 [==============================] - 1s 48us/sample - loss: 0.2594 - acc: 0.8825
# Epoch 12/100
# 17331/17331 [==============================] - 1s 50us/sample - loss: 0.2454 - acc: 0.8890
# Epoch 13/100
# 17331/17331 [==============================] - 1s 48us/sample - loss: 0.2355 - acc: 0.8931
# Epoch 14/100
# 17331/17331 [==============================] - 1s 48us/sample - loss: 0.2269 - acc: 0.8983
# Epoch 15/100
# 17331/17331 [==============================] - 1s 47us/sample - loss: 0.2263 - acc: 0.9001
# Epoch 16/100
# 17331/17331 [==============================] - 1s 48us/sample - loss: 0.2165 - acc: 0.9017
# Epoch 17/100
# 17331/17331 [==============================] - 1s 50us/sample - loss: 0.2079 - acc: 0.9084
# Epoch 18/100
# 17331/17331 [==============================] - 1s 51us/sample - loss: 0.2052 - acc: 0.9085
# Epoch 19/100
# 17331/17331 [==============================] - 1s 47us/sample - loss: 0.2008 - acc: 0.9118
# Epoch 20/100
# 17331/17331 [==============================] - 1s 44us/sample - loss: 0.1854 - acc: 0.9151
# Epoch 21/100
# 17331/17331 [==============================] - 1s 40us/sample - loss: 0.1952 - acc: 0.9121
# Epoch 22/100
# 17331/17331 [==============================] - 1s 45us/sample - loss: 0.1932 - acc: 0.9145
# Epoch 23/100
# 17331/17331 [==============================] - 1s 43us/sample - loss: 0.1833 - acc: 0.9171
# Epoch 24/100
# 17331/17331 [==============================] - 1s 45us/sample - loss: 0.1713 - acc: 0.9226
# Epoch 25/100
# 17331/17331 [==============================] - 1s 42us/sample - loss: 0.1649 - acc: 0.9244
# Epoch 26/100
# 17331/17331 [==============================] - 1s 41us/sample - loss: 0.1700 - acc: 0.9202
# Epoch 27/100
# 17331/17331 [==============================] - 1s 42us/sample - loss: 0.1836 - acc: 0.9188
# Epoch 28/100
# 17331/17331 [==============================] - 1s 41us/sample - loss: 0.1758 - acc: 0.9206
# Epoch 29/100
# 17331/17331 [==============================] - 1s 40us/sample - loss: 0.1618 - acc: 0.9252
# Epoch 30/100
# 17331/17331 [==============================] - 1s 40us/sample - loss: 0.1650 - acc: 0.9227
# Epoch 31/100
# 17331/17331 [==============================] - 1s 39us/sample - loss: 0.1591 - acc: 0.9269
# Epoch 32/100
# 17331/17331 [==============================] - 1s 39us/sample - loss: 0.1625 - acc: 0.9268
# Epoch 33/100
# 17331/17331 [==============================] - 1s 39us/sample - loss: 0.1707 - acc: 0.9216
# Epoch 34/100
# 17331/17331 [==============================] - 1s 41us/sample - loss: 0.1678 - acc: 0.9242
# Epoch 35/100
# 17331/17331 [==============================] - 1s 39us/sample - loss: 0.1565 - acc: 0.9272
# Epoch 36/100
# 17331/17331 [==============================] - 1s 41us/sample - loss: 0.1487 - acc: 0.9303
# Epoch 37/100
# 17331/17331 [==============================] - 1s 41us/sample - loss: 0.1421 - acc: 0.9319
# Epoch 38/100
# 17331/17331 [==============================] - 1s 40us/sample - loss: 0.1394 - acc: 0.9335
# Epoch 39/100
# 17331/17331 [==============================] - 1s 42us/sample - loss: 0.1415 - acc: 0.9338
# Epoch 40/100
# 17331/17331 [==============================] - 1s 43us/sample - loss: 0.1371 - acc: 0.9330
# Epoch 41/100
# 17331/17331 [==============================] - 1s 42us/sample - loss: 0.1381 - acc: 0.9337
# Epoch 42/100
# 17331/17331 [==============================] - 1s 44us/sample - loss: 0.1475 - acc: 0.9289
# Epoch 43/100
# 17331/17331 [==============================] - 1s 40us/sample - loss: 0.1734 - acc: 0.9217
# Epoch 44/100
# 17331/17331 [==============================] - 1s 42us/sample - loss: 0.1730 - acc: 0.9229
# Epoch 45/100
# 17331/17331 [==============================] - 1s 41us/sample - loss: 0.1618 - acc: 0.9272
# Epoch 46/100
# 17331/17331 [==============================] - 1s 42us/sample - loss: 0.1538 - acc: 0.9306
# Epoch 47/100
# 17331/17331 [==============================] - 1s 43us/sample - loss: 0.1549 - acc: 0.9300
# Epoch 48/100
# 17331/17331 [==============================] - 1s 43us/sample - loss: 0.1503 - acc: 0.9310
# Epoch 49/100
# 17331/17331 [==============================] - 1s 42us/sample - loss: 0.1473 - acc: 0.9310
# Epoch 50/100
# 17331/17331 [==============================] - 1s 43us/sample - loss: 0.1363 - acc: 0.9338
# Epoch 51/100
# 17331/17331 [==============================] - 1s 43us/sample - loss: 0.1328 - acc: 0.9345
# Epoch 52/100
# 17331/17331 [==============================] - 1s 43us/sample - loss: 0.1316 - acc: 0.9354
# Epoch 53/100
# 17331/17331 [==============================] - 1s 42us/sample - loss: 0.1316 - acc: 0.9349
# Epoch 54/100
# 17331/17331 [==============================] - 1s 43us/sample - loss: 0.1347 - acc: 0.9366
# Epoch 55/100
# 17331/17331 [==============================] - 1s 41us/sample - loss: 0.1311 - acc: 0.9369
# Epoch 56/100
# 17331/17331 [==============================] - 1s 42us/sample - loss: 0.1475 - acc: 0.9327
# Epoch 57/100
# 17331/17331 [==============================] - 1s 41us/sample - loss: 0.1664 - acc: 0.9255
# Epoch 58/100
# 17331/17331 [==============================] - 1s 41us/sample - loss: 0.1559 - acc: 0.9283
# Epoch 59/100
# 17331/17331 [==============================] - 1s 43us/sample - loss: 0.1384 - acc: 0.9326
# Epoch 60/100
# 17331/17331 [==============================] - 1s 43us/sample - loss: 0.1331 - acc: 0.9354
# Epoch 61/100
# 17331/17331 [==============================] - 1s 42us/sample - loss: 0.1462 - acc: 0.9339
# Epoch 62/100
# 17331/17331 [==============================] - 1s 43us/sample - loss: 0.1371 - acc: 0.9332
# Epoch 63/100
# 17331/17331 [==============================] - 1s 41us/sample - loss: 0.1355 - acc: 0.9339
# Epoch 64/100
# 17331/17331 [==============================] - 1s 41us/sample - loss: 0.1316 - acc: 0.9351
# Epoch 65/100
# 17331/17331 [==============================] - 1s 45us/sample - loss: 0.1282 - acc: 0.9373
# Epoch 66/100
# 17331/17331 [==============================] - 1s 45us/sample - loss: 0.1280 - acc: 0.9382
# Epoch 67/100
# 17331/17331 [==============================] - 1s 45us/sample - loss: 0.1265 - acc: 0.9370
# Epoch 68/100
# 17331/17331 [==============================] - 1s 46us/sample - loss: 0.1278 - acc: 0.9366
# Epoch 69/100
# 17331/17331 [==============================] - 1s 43us/sample - loss: 0.1258 - acc: 0.9377
# Epoch 70/100
# 17331/17331 [==============================] - 1s 41us/sample - loss: 0.1258 - acc: 0.9375
# Epoch 71/100
# 17331/17331 [==============================] - 1s 42us/sample - loss: 0.1269 - acc: 0.9377
# Epoch 72/100
# 17331/17331 [==============================] - 1s 42us/sample - loss: 0.1301 - acc: 0.9366
# Epoch 73/100
# 17331/17331 [==============================] - 1s 41us/sample - loss: 0.1460 - acc: 0.9316
# Epoch 74/100
# 17331/17331 [==============================] - 1s 44us/sample - loss: 0.1599 - acc: 0.9298
# Epoch 75/100
# 17331/17331 [==============================] - 1s 41us/sample - loss: 0.1644 - acc: 0.9300
# Epoch 76/100
# 17331/17331 [==============================] - 1s 44us/sample - loss: 0.1451 - acc: 0.9338
# Epoch 77/100
# 17331/17331 [==============================] - 1s 43us/sample - loss: 0.1520 - acc: 0.9317
# Epoch 78/100
# 17331/17331 [==============================] - 1s 44us/sample - loss: 0.1418 - acc: 0.9361
# Epoch 79/100
# 17331/17331 [==============================] - 1s 44us/sample - loss: 0.1310 - acc: 0.9356
# Epoch 80/100
# 17331/17331 [==============================] - 1s 44us/sample - loss: 0.1255 - acc: 0.9384
# Epoch 81/100
# 17331/17331 [==============================] - 1s 41us/sample - loss: 0.1276 - acc: 0.9384
# Epoch 82/100
# 17331/17331 [==============================] - 1s 42us/sample - loss: 0.1388 - acc: 0.9346
# Epoch 83/100
# 17331/17331 [==============================] - 1s 42us/sample - loss: 0.1318 - acc: 0.9357
# Epoch 84/100
# 17331/17331 [==============================] - 1s 40us/sample - loss: 0.1308 - acc: 0.9370
# Epoch 85/100
# 17331/17331 [==============================] - 1s 41us/sample - loss: 0.1255 - acc: 0.9395
# Epoch 86/100
# 17331/17331 [==============================] - 1s 41us/sample - loss: 0.1223 - acc: 0.9389
# Epoch 87/100
# 17331/17331 [==============================] - 1s 41us/sample - loss: 0.1234 - acc: 0.9388
# Epoch 88/100
# 17331/17331 [==============================] - 1s 42us/sample - loss: 0.1220 - acc: 0.9386
# Epoch 89/100
# 17331/17331 [==============================] - 1s 40us/sample - loss: 0.1239 - acc: 0.9391
# Epoch 90/100
# 17331/17331 [==============================] - 1s 44us/sample - loss: 0.1224 - acc: 0.9392
# Epoch 91/100
# 17331/17331 [==============================] - 1s 44us/sample - loss: 0.1270 - acc: 0.9383
# Epoch 92/100
# 17331/17331 [==============================] - 1s 42us/sample - loss: 0.1282 - acc: 0.9375
# Epoch 93/100
# 17331/17331 [==============================] - 1s 44us/sample - loss: 0.1287 - acc: 0.9381
# Epoch 94/100
# 17331/17331 [==============================] - 1s 43us/sample - loss: 0.1249 - acc: 0.9373
# Epoch 95/100
# 17331/17331 [==============================] - 1s 43us/sample - loss: 0.1214 - acc: 0.9390
# Epoch 96/100
# 17331/17331 [==============================] - 1s 40us/sample - loss: 0.1236 - acc: 0.9385
# Epoch 97/100
# 17331/17331 [==============================] - 1s 39us/sample - loss: 0.1193 - acc: 0.9405
# Epoch 98/100
# 17331/17331 [==============================] - 1s 42us/sample - loss: 0.1197 - acc: 0.9405
# Epoch 99/100
# 17331/17331 [==============================] - 1s 43us/sample - loss: 0.1186 - acc: 0.9395
# Epoch 100/100
# 17331/17331 [==============================] - 1s 41us/sample - loss: 0.1486 - acc: 0.9347

# %%
y_pred=classifier.predict(X_test)
y_pred =(y_pred>0.5)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[2286  781]
#  [ 702 3659]]

# %%
#this is an 80% accuracy on the test set!!
# Out:
# (7428,)
